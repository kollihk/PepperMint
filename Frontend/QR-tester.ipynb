# %%
import qrcode
import pandas as pd
from more_itertools import one
import cv2

# %%
df= pd.read_csv("./products_DB/product_info.csv", index_col=3)
df
# Out:
#                                                         hashcode brand  \
# serial_number
# 72946928       9F86D081884C7D659A2FEAA0C55AD015A3BF4F1B2B0B82...  Nike
# 72983945       59830EBC3A4184110566BF1A290D08473DFDCBD492CE49...  Nike
# 64667693       483BCE6C28016C4CF9BB61C12B5844D506E76A85B27E5B...  Nike
# 46277522       D4B562A23B7B6DD3044071DE630867AB2EA3B19918C2B4...  Nike
# 35427668       1DF366BEE8FE93AC0E5162E6802A9F0BCD22E854CA060C...  Nike
# 84384394       3BE2748F9B431DDBC1014DEE025179C8D698E0F7E4B699...  Nike
# 59922397       D71D18478FA45442AEEF766065188268C1FFB5865E409C...  Nike
# 97562935       29B88A7D4C57D8E4F2D6083AC3638138167E864775DE31...  Nike
# 62636499       E68D7459C7958300CE197BF3096C3D39E0CB70376A3D7C...  Nike
#
#                                model        color_name color_hex  size  \
# serial_number
# 72946928       Secret NFT Collection  Atomic tangerine   #FF9966    40
# 72983945       Secret NFT Collection           Catawba   #703642    40
# 64667693       Secret NFT Collection   Electric purple   #BF00FF    40
# 46277522       Secret NFT Collection         Firebrick   #B22222    40
# 35427668       Secret NFT Collection  Medium turquoise   #48D1CC    40
# 84384394       Secret NFT Collection             Melon   #FEBAAD    40
# 59922397       Secret NFT Collection     Midnight blue   #191970    40
# 97562935       Secret NFT Collection        Seal brown   #59260B    40
# 62636499       Secret NFT Collection        Vegas gold   #C5B358    40
#
#                      feature minted
# serial_number
# 72946928               wings      F
# 72983945          reflective      F
# 64667693                soft      F
# 46277522         water_proof      F
# 35427668             olympic      F
# 84384394           embosssed      F
# 59922397             glowing      F
# 97562935       scratch_proof      F
# 62636499            stardust      F

# %%
# THIS CODE IS RUN ONLY ONCE to generate the QR codes for "Nike Secret NFT Collection"
# Simulating the Manufacturer's Database for product authentication.
# i = 0
# while i< 9:
#     file_name = str(df['serial_number'].iloc[i]) + ".png"
#     file_path = f"./products_DB/products_image/{file_name}"
#     code = str(df['hashcode'].iloc[i])
#     img = qrcode.make(code)
#     img.save(file_path)    
#     i += 1

# img.show(file_path)
# print(f"{file_name} is saved in {file_path}")

# %%
# capture = cv2.VideoCapture(0)
# # initialize the cv2 QRCode detector
# detector = cv2.QRCodeDetector()

# while True:
#     _,img = capture.read()    
#     # detect and decode
#     data, one, _ = detector.detectAndDecode(img)
#     # check if there is a QRCode in the image
#     if data:
#         product_hashcode = data
#         break
#     cv2.imshow('Scan Your Product QR code', img)
#     if cv2.waitKey(1) == chr(27):
#         break

# # b=webbrowser.open(str(a))
# print(f"product hashcode: {product_hashcode}")
# capture.release()
# cv2.destroyAllWindows()
